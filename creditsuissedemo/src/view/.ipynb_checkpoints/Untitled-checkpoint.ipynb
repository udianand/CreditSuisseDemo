# %%
from elasticsearch import Elasticsearch 



es=Elasticsearch([{'host':'192.168.231.142','port':9200}])


keyword = ["Education","Sustainable"''
#res=es.get(index='user_profile',doc_type='individual',id=1)
#print(res['_source']['EmailInfo'])

# %%
res = es.search(index="tweetstream", doc_type="tweet", body={"query": {"match": {"message": keyword}}}, size=1000, from_=0)

# %%
res
# Out:
# {'took': 74,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': 1851,
#   'max_score': 1.1544023,
#   'hits': [{'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'dN2W2WkBgNd_yIScV_Fp',
#     '_score': 1.1544023,
#     '_source': {'author': 'roseayy_red',
#      'date': 'Mon Apr 01 15:48:17 +0000 2019',
#      'message': '‼️ education yourselves.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'z92W2WkBgNd_yISc9fLW',
#     '_score': 1.1464117,
#     '_source': {'author': 'DrVEvansWinters',
#      'date': 'Mon Apr 01 15:48:57 +0000 2019',
#      'message': 'Decolonizing education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'kt2W2WkBgNd_yISc2fLR',
#     '_score': 1.1370066,
#     '_source': {'author': 'DJRell803',
#      'date': 'Mon Apr 01 15:48:50 +0000 2019',
#      'message': 'Self Education is 🔑'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'yt2b2WkBgNd_yIScOfsd',
#     '_score': 1.1370066,
#     '_source': {'author': 'candicegiove',
#      'date': 'Mon Apr 01 15:53:37 +0000 2019',
#      'message': 'Education funding fail ✏️📓📏    👇👇👇'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'q92c2WkBgNd_yIScGv05',
#     '_score': 1.075985,
#     '_source': {'author': 'aBergsEyeView',
#      'date': 'Mon Apr 01 15:54:34 +0000 2019',
#      'message': 'Interesting article from @rezendi discussing traditional education versus new trade-focused education options like… https://t.co/0qClxO6DFf'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'iN2b2WkBgNd_yISclPzS',
#     '_score': 1.0737871,
#     '_source': {'author': 'usajoblist',
#      'date': 'Mon Apr 01 15:54:00 +0000 2019',
#      'message': 'Education Intern https://t.co/LDM4v9tZAM'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'gd2Z2WkBgNd_yIScqPiL',
#     '_score': 1.0583607,
#     '_source': {'author': 'facestained',
#      'date': 'Mon Apr 01 15:51:54 +0000 2019',
#      'message': '@RoeRhodie Frick the education system'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '792b2WkBgNd_yIScSPtq',
#     '_score': 1.0500445,
#     '_source': {'author': 'theblackcowgirl',
#      'date': 'Mon Apr 01 15:53:41 +0000 2019',
#      'message': 'RT @DJRell803: Self Education is 🔑'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'y92W2WkBgNd_yISc9PI2',
#     '_score': 1.0457833,
#     '_source': {'author': 'iamarmedwithkn4',
#      'date': 'Mon Apr 01 15:48:57 +0000 2019',
#      'message': '@AOC When you devalue the educator you devalue the education.  @AFTWV #education #publicschools'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Id2c2WkBgNd_yIScvv_Q',
#     '_score': 1.0438695,
#     '_source': {'author': 'avySalandanan',
#      'date': 'Mon Apr 01 15:55:16 +0000 2019',
#      'message': 'nw: Sex Education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Md2c2WkBgNd_yIScWP5k',
#     '_score': 1.0288613,
#     '_source': {'author': 'Shosho_Figo',
#      'date': 'Mon Apr 01 15:54:50 +0000 2019',
#      'message': 'RT @osamasalama500: Dammit i hate education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'zt2W2WkBgNd_yIScf_HQ',
#     '_score': 1.0225679,
#     '_source': {'author': 'BkayO1',
#      'date': 'Mon Apr 01 15:48:27 +0000 2019',
#      'message': 'RT @LRFZimbabwe: @parliamentzim is holding public consultations on the Education Amendment  Bill. The revamping of the Education Act, shoul…'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'yt2a2WkBgNd_yIScx_o7',
#     '_score': 1.0225679,
#     '_source': {'author': 'tmj_orf_edu',
#      'date': 'Mon Apr 01 15:53:08 +0000 2019',
#      'message': 'This job might be a great fit for you: Education Services Facilitator, FFSP - https://t.co/zQiipqYFL5 #Education #VirginiaBeach, VA'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'PN2a2WkBgNd_yISchvos',
#     '_score': 1.0183649,
#     '_source': {'author': 'ghostoflenin',
#      'date': 'Mon Apr 01 15:52:51 +0000 2019',
#      'message': "@HalfAtlanta can u clarify? I'm not familiar with the concept of mass political education, or mass education at all tbh"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Ht2Y2WkBgNd_yISc6ve6',
#     '_score': 1.0183649,
#     '_source': {'author': 'TheUnionUCL',
#      'date': 'Mon Apr 01 15:51:06 +0000 2019',
#      'message': 'RT @UCL_teaching: The Education Awards 2019 shortlist announced: read the full list of @TheUnionUCL Student Choice Awards and UCL Education…'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Ht2Y2WkBgNd_yIScdfb7',
#     '_score': 1.0172275,
#     '_source': {'author': 'David50322604',
#      'date': 'Mon Apr 01 15:50:35 +0000 2019',
#      'message': 'She needs an education! 😂 https://t.co/3RfF6IuA9J'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'zN2W2WkBgNd_yIScEfDx',
#     '_score': 1.0172275,
#     '_source': {'author': 'LablyLots',
#      'date': 'Mon Apr 01 15:47:59 +0000 2019',
#      'message': '@ilovejamilll Riverdale, Sex Education, at Umbrella Academy'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'ht2Y2WkBgNd_yIScMPWe',
#     '_score': 1.0049567,
#     '_source': {'author': 'BridgitteLesley',
#      'date': 'Mon Apr 01 15:50:18 +0000 2019',
#      'message': 'Ups and downs and all the in-betweens. It would be an education! \n\n★AN EDUCATION!★\n\nhttps://t.co/pFH23U499d… https://t.co/RtAfYKjVUR'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '4d2c2WkBgNd_yISco_5-',
#     '_score': 1.0027444,
#     '_source': {'author': 'hadi_masuma',
#      'date': 'Mon Apr 01 15:55:10 +0000 2019',
#      'message': '@Hidi2200 LOOOOL someone requires some education there'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'BN2a2WkBgNd_yISc4Pu3',
#     '_score': 0.9943229,
#     '_source': {'author': 'EddieDonovan',
#      'date': 'Mon Apr 01 15:53:14 +0000 2019',
#      'message': 'RT @DebraBuenik: @EddieDonovan @JeanOtero2120 @SherrieRogge1 @realDonaldTrump Education.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Fd2a2WkBgNd_yIScd_oa',
#     '_score': 0.9856674,
#     '_source': {'author': 'JeyyTheVillain',
#      'date': 'Mon Apr 01 15:52:47 +0000 2019',
#      'message': '@somalijawn American education is shit'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Md2X2WkBgNd_yIScJfNq',
#     '_score': 0.9856674,
#     '_source': {'author': 'aimbillofwright',
#      'date': 'Mon Apr 01 15:49:10 +0000 2019',
#      'message': 'RT @TraOnna_: Education is POWER'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'A92a2WkBgNd_yIScbvoO',
#     '_score': 0.9803943,
#     '_source': {'author': 'mra_mb',
#      'date': 'Mon Apr 01 15:52:45 +0000 2019',
#      'message': 'RT @thisismrking: Want to learn more about inquiry education? Check out Ep 19 of The Shape of Education to Come! Stream/download here: \n\nht…'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'UN2X2WkBgNd_yIScqvRD',
#     '_score': 0.9770722,
#     '_source': {'author': 'nawal_zgh',
#      'date': 'Mon Apr 01 15:49:44 +0000 2019',
#      'message': 'RT @asticky1still: Netflix          Twitter \n              🤝\nFucking up your education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'st2X2WkBgNd_yISc2PTc',
#     '_score': 0.9770722,
#     '_source': {'author': 'TheMovieProjec1',
#      'date': 'Mon Apr 01 15:49:56 +0000 2019',
#      'message': '@RealPremShady Welcome to the Ontario Conservative education system.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'tN2c2WkBgNd_yIScHv05',
#     '_score': 0.9770722,
#     '_source': {'author': 'AhmedMokhtar97',
#      'date': 'Mon Apr 01 15:54:35 +0000 2019',
#      'message': 'RT @asticky1still: Netflix          Twitter \n              🤝\nFucking up your education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Vd2a2WkBgNd_yIScG_nQ',
#     '_score': 0.9760065,
#     '_source': {'author': 'JessNovakk',
#      'date': 'Mon Apr 01 15:52:24 +0000 2019',
#      'message': 'RT @asticky1still: Netflix          Twitter \n              🤝\nFucking up your education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'dd2X2WkBgNd_yIScvPRL',
#     '_score': 0.9760065,
#     '_source': {'author': 'usajoblist',
#      'date': 'Mon Apr 01 15:49:48 +0000 2019',
#      'message': 'Education &amp; Licensure Program\xa0Assistant https://t.co/gFkz97nb9o'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'fd2b2WkBgNd_yISckPxb',
#     '_score': 0.9696508,
#     '_source': {'author': 'imrnbsh',
#      'date': 'Mon Apr 01 15:53:59 +0000 2019',
#      'message': 'RT @DellAnnaLuca: 10 THESES ON EDUCATION:\n\n1/ Higher education has been built around the needs of the universities, not of the students.\n\nT…'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '7d2Z2WkBgNd_yISc3vhj',
#     '_score': 0.96862245,
#     '_source': {'author': 'Safeerah11',
#      'date': 'Mon Apr 01 15:52:08 +0000 2019',
#      'message': 'RT @asticky1still: Netflix          Twitter \n              🤝\nFucking up your education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Lt2a2WkBgNd_yISc9ft3',
#     '_score': 0.96862245,
#     '_source': {'author': 'GirlBeret',
#      'date': 'Mon Apr 01 15:53:20 +0000 2019',
#      'message': '@erasmus_wikus @veryfarwest @morrisianj No. Education and economic freedom'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '2N2c2WkBgNd_yIScn_7E',
#     '_score': 0.96862245,
#     '_source': {'author': 'amrlazrnn',
#      'date': 'Mon Apr 01 15:55:09 +0000 2019',
#      'message': 'RT @asticky1still: Netflix          Twitter \n              🤝\nFucking up your education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Rd2W2WkBgNd_yISctfLx',
#     '_score': 0.96862245,
#     '_source': {'author': 'clranina',
#      'date': 'Mon Apr 01 15:48:41 +0000 2019',
#      'message': '@11_diah karena "not well mannered" pemicunya dari education 💩'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Rt2b2WkBgNd_yIScd_wV',
#     '_score': 0.96862245,
#     '_source': {'author': 'RoohanNadim',
#      'date': 'Mon Apr 01 15:53:53 +0000 2019',
#      'message': 'RT @asticky1still: Netflix          Twitter \n              🤝\nFucking up your education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'id2V2WkBgNd_yISc8vAv',
#     '_score': 0.9663281,
#     '_source': {'author': 'CathyFoyt',
#      'date': 'Mon Apr 01 15:47:51 +0000 2019',
#      'message': '@FLOTUS Think your husband could use some character education?🧐'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'wd2c2WkBgNd_yIScJf1g',
#     '_score': 0.9663281,
#     '_source': {'author': 'mariaaadeniceee',
#      'date': 'Mon Apr 01 15:54:37 +0000 2019',
#      'message': 'RT @GoDiegitoGo: focus on getting that money and education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'G92a2WkBgNd_yISc6fvP',
#     '_score': 0.9663281,
#     '_source': {'author': 'mariamfaraheen',
#      'date': 'Mon Apr 01 15:53:17 +0000 2019',
#      'message': 'Only dumb people say “education is not for me”'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '9d2c2WkBgNd_yIScO_0S',
#     '_score': 0.9653206,
#     '_source': {'author': 'karryjay',
#      'date': 'Mon Apr 01 15:54:43 +0000 2019',
#      'message': "RT @ItsMutai: I'm for 100% #HELBWaiver. Is time we petition the new education CS to effect the HELB Waiver! Education should not be slavery."}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'MN2Z2WkBgNd_yIScffhR',
#     '_score': 0.9653206,
#     '_source': {'author': 'cyprianongeri1',
#      'date': 'Mon Apr 01 15:51:43 +0000 2019',
#      'message': "RT @ItsMutai: I'm for 100% #HELBWaiver. Is time we petition the new education CS to effect the HELB Waiver! Education should not be slavery."}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '0d2a2WkBgNd_yIScUfmw',
#     '_score': 0.960549,
#     '_source': {'author': 'DanielJaiy',
#      'date': 'Mon Apr 01 15:52:38 +0000 2019',
#      'message': "I'd put the environment after education though. I guess it would be just a part of the education really🤷\u200d♂️"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '092W2WkBgNd_yIScgfFv',
#     '_score': 0.9589342,
#     '_source': {'author': 'usajoblist',
#      'date': 'Mon Apr 01 15:48:28 +0000 2019',
#      'message': 'Clinical Education Specialist https://t.co/TdBI6w7lRK'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'td2Y2WkBgNd_yIScwPZd',
#     '_score': 0.95268166,
#     '_source': {'author': 'daisyroblesss_',
#      'date': 'Mon Apr 01 15:50:55 +0000 2019',
#      'message': 'RT @GoDiegitoGo: focus on getting that money and education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '3N2W2WkBgNd_yISciPFu',
#     '_score': 0.9515646,
#     '_source': {'author': 'mayyrrraa',
#      'date': 'Mon Apr 01 15:48:29 +0000 2019',
#      'message': 'RT @GoDiegitoGo: focus on getting that money and education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Sd2Y2WkBgNd_yISchPY1',
#     '_score': 0.9515646,
#     '_source': {'author': 'David50322604',
#      'date': 'Mon Apr 01 15:50:39 +0000 2019',
#      'message': 'RT @David50322604: She needs an education! 😂 https://t.co/3RfF6IuA9J'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '5t2Z2WkBgNd_yIScUvc2',
#     '_score': 0.9451942,
#     '_source': {'author': 'aubviouslydying',
#      'date': 'Mon Apr 01 15:51:32 +0000 2019',
#      'message': "RT @elliebegood: 'sEx EdUcAtIoN iS iMmOrAL'\n\nthanks to lack of sex education I was raped at 14 and thought it was normal, lost my virginity…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Ud2a2WkBgNd_yIScGvlM',
#     '_score': 0.94421715,
#     '_source': {'author': 'aimeenavarretee',
#      'date': 'Mon Apr 01 15:52:23 +0000 2019',
#      'message': 'RT @GoDiegitoGo: focus on getting that money and education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'g92a2WkBgNd_yIScMfm0',
#     '_score': 0.9427418,
#     '_source': {'author': 'ldfabre',
#      'date': 'Mon Apr 01 15:52:29 +0000 2019',
#      'message': 'Please “run away to the hills” and leave education alone! 🙏🏻🙏🏻🙏🏻'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'S92c2WkBgNd_yIScZf4J',
#     '_score': 0.9336128,
#     '_source': {'author': 'lizbeth_basilio',
#      'date': 'Mon Apr 01 15:54:54 +0000 2019',
#      'message': 'Enserio les recomiendo la serie "sex education"👍'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'r92X2WkBgNd_yISc1_Qu',
#     '_score': 0.9336128,
#     '_source': {'author': 'jonliedtke',
#      'date': 'Mon Apr 01 15:49:55 +0000 2019',
#      'message': "@LisaThompsonMPP You're destroying education in the province."}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'tt2X2WkBgNd_yIScY_Po',
#     '_score': 0.9294791,
#     '_source': {'author': 'Gineeorshine81',
#      'date': 'Mon Apr 01 15:49:26 +0000 2019',
#      'message': 'RT @KorteSupremo_: Philippine education system’s sad reality. 👇🏻 https://t.co/vzpPmdB1ap'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'id2Y2WkBgNd_yIScp_Zp',
#     '_score': 0.9283169,
#     '_source': {'author': 'fssdPGMS',
#      'date': 'Mon Apr 01 15:50:48 +0000 2019',
#      'message': 'Poplar Grove Post | Smore Newsletters for Education https://t.co/cEiWRMZLCT'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'wt2a2WkBgNd_yIScTPm7',
#     '_score': 0.9283169,
#     '_source': {'author': 'kisselovaaa',
#      'date': 'Mon Apr 01 15:52:36 +0000 2019',
#      'message': 'RT @KorteSupremo_: Philippine education system’s sad reality. 👇🏻 https://t.co/vzpPmdB1ap'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '_d2b2WkBgNd_yISczPxO',
#     '_score': 0.9283169,
#     '_source': {'author': 'cryptpride29',
#      'date': 'Mon Apr 01 15:54:14 +0000 2019',
#      'message': 'RT @Elexonic: We don’t need no education? https://t.co/LCIltx830E'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '0N2Z2WkBgNd_yIScRfd2',
#     '_score': 0.9210114,
#     '_source': {'author': 'LcNeveees',
#      'date': 'Mon Apr 01 15:51:29 +0000 2019',
#      'message': 'Sex Education, essa série e maneirinha kkkkkkkk to rindo muito'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '292Y2WkBgNd_yIScz_YR',
#     '_score': 0.9110471,
#     '_source': {'author': 'tnceccan',
#      'date': 'Mon Apr 01 15:50:58 +0000 2019',
#      'message': "What's the State of Special Education?\n\nAs a special education professional, what do you think about the state of o… https://t.co/ERP4SqZpdw"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'bN2V2WkBgNd_yISc5vBX',
#     '_score': 0.9095943,
#     '_source': {'author': 'Keeshfrom117da1',
#      'date': 'Mon Apr 01 15:47:48 +0000 2019',
#      'message': '@llilfoot May you finesse the education system king'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'yd2Y2WkBgNd_yIScTvUg',
#     '_score': 0.9095943,
#     '_source': {'author': 'abdelrahmaneidd',
#      'date': 'Mon Apr 01 15:50:26 +0000 2019',
#      'message': 'RT @asticky1still: Netflix          Twitter \n              🤝\nFucking up your education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'a92Y2WkBgNd_yIScl_YG',
#     '_score': 0.9095943,
#     '_source': {'author': 'gl_mlk2',
#      'date': 'Mon Apr 01 15:50:44 +0000 2019',
#      'message': 'RT @asticky1still: Netflix          Twitter \n              🤝\nFucking up your education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Ut2a2WkBgNd_yIScjvoL',
#     '_score': 0.90738004,
#     '_source': {'author': 'she__butitsCOOL',
#      'date': 'Mon Apr 01 15:52:53 +0000 2019',
#      'message': 'I’ve made so many sacrifices to secure my education it’s crazy 😓'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'jN2b2WkBgNd_yIScl_zR',
#     '_score': 0.90617806,
#     '_source': {'author': 'CaNitishGarg89',
#      'date': 'Mon Apr 01 15:54:01 +0000 2019',
#      'message': '@dibang @abpnewshindi where stand Education and healthcare schemes in their goverment.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Bd2Z2WkBgNd_yIScZfhJ',
#     '_score': 0.90617806,
#     '_source': {'author': 'DanielJaiy',
#      'date': 'Mon Apr 01 15:51:37 +0000 2019',
#      'message': "I'm mad you don't have education 5 times, but solid list"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'n92c2WkBgNd_yIScFv0O',
#     '_score': 0.89945865,
#     '_source': {'author': 'simplyndech',
#      'date': 'Mon Apr 01 15:54:33 +0000 2019',
#      'message': "RT @ItsMutai: I'm for 100% #HELBWaiver. Is time we petition the new education CS to effect the HELB Waiver! Education should not be slavery."}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '8d2Z2WkBgNd_yISc3_gP',
#     '_score': 0.8989189,
#     '_source': {'author': 'OnePupil',
#      'date': 'Mon Apr 01 15:52:08 +0000 2019',
#      'message': '#PupilsRun https://t.co/mZZzT6FAoz\nSupporting children education #STEAM https://t.co/koYvya2Vg9'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '-t2Y2WkBgNd_yISc3fZq',
#     '_score': 0.8989189,
#     '_source': {'author': 'fssdPGMS',
#      'date': 'Mon Apr 01 15:51:02 +0000 2019',
#      'message': 'Poplar Grove en ESPAÑOL | Smore Newsletters for Education https://t.co/iUhIuuRwgi'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '6N2Y2WkBgNd_yISc1PZv',
#     '_score': 0.89886284,
#     '_source': {'author': 'troujiwoo',
#      'date': 'Mon Apr 01 15:51:00 +0000 2019',
#      'message': 'Education: Criminology.\n\nLife motto: Dont do it if u dont like it.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Xd2b2WkBgNd_yIScCPux',
#     '_score': 0.89886284,
#     '_source': {'author': 'libertypourtous',
#      'date': 'Mon Apr 01 15:53:24 +0000 2019',
#      'message': 'Épanouissement à l’école....\n#DESSIN #SOCIÉTÉ #Education #bourrageDeCrâne #esclave #systeme https://t.co/QIAUiCf9AT'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '3N2b2WkBgNd_yIScvvw2',
#     '_score': 0.89886284,
#     '_source': {'author': 'RoyalTrendia',
#      'date': 'Mon Apr 01 15:54:11 +0000 2019',
#      'message': 'Public Education Is Key To Boosting Investor Confidence\n...\nhttps://t.co/jB7Pl1lTJq\n\n#SundownerKBC'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'AN2X2WkBgNd_yIScDfOU',
#     '_score': 0.8867807,
#     '_source': {'author': 'LiamBel35195950',
#      'date': 'Mon Apr 01 15:49:04 +0000 2019',
#      'message': '@NetflixUK @netflix anymore episodes of Sex Education to come?'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 's92b2WkBgNd_yIScrPw9',
#     '_score': 0.8867807,
#     '_source': {'author': 'deymex3',
#      'date': 'Mon Apr 01 15:54:06 +0000 2019',
#      'message': 'RT @GoDiegitoGo: focus on getting that money and education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'V92c2WkBgNd_yISca_4Y',
#     '_score': 0.8867807,
#     '_source': {'author': 'OGPOA2',
#      'date': 'Mon Apr 01 15:54:55 +0000 2019',
#      'message': 'We are attending 2019 Education Day  https://t.co/TbJv5LwMaB'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'W92X2WkBgNd_yIScr_Rr',
#     '_score': 0.88630724,
#     '_source': {'author': 'MosleyNylan',
#      'date': 'Mon Apr 01 15:49:45 +0000 2019',
#      'message': 'Imma definitely destroy the government with education👨🏾\u200d🎓🙏🏾‼️. Gotta do it for Nipsey ‼️.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Zd2Z2WkBgNd_yIScD_cZ',
#     '_score': 0.88507056,
#     '_source': {'author': 'Smile_Education',
#      'date': 'Mon Apr 01 15:51:15 +0000 2019',
#      'message': 'Maths Teacher , Birmingham, £130-200, Education &amp; Training https://t.co/0rGpbwVJXF #jobs'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '8N2c2WkBgNd_yIScOf3U',
#     '_score': 0.88507056,
#     '_source': {'author': 'janwat',
#      'date': 'Mon Apr 01 15:54:43 +0000 2019',
#      'message': '@Gravit80 Ah Wyatt - putting that Harvard education to work for a change.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '8t2X2WkBgNd_yIScBPLc',
#     '_score': 0.88507056,
#     '_source': {'author': 'gummycore',
#      'date': 'Mon Apr 01 15:49:01 +0000 2019',
#      'message': 'RT @yourfavisbald2: Baldi (Baldi’s Basics in Education &amp; Learning) https://t.co/HHbMDzTz3W'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Ld2b2WkBgNd_yIScaPxK',
#     '_score': 0.88507056,
#     '_source': {'author': 'AntoFlynnser',
#      'date': 'Mon Apr 01 15:53:49 +0000 2019',
#      'message': 'Bigotry is a disease best dealt with through education https://t.co/2DjXZxGmvk'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Ad2Y2WkBgNd_yIScavau',
#     '_score': 0.87842023,
#     '_source': {'author': 'UniqueLittleHa1',
#      'date': 'Mon Apr 01 15:50:33 +0000 2019',
#      'message': 'Hello April!!! #springtime #aprilfoolsday #goodfriday #easter #education #daycare #franklin #virginia… https://t.co/eCbkBsEPnH'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'tN2a2WkBgNd_yIScvfoD',
#     '_score': 0.87842023,
#     '_source': {'author': 'AiveeZaneSicat',
#      'date': 'Mon Apr 01 15:53:05 +0000 2019',
#      'message': 'Dude bachelor of secondary education major in mathematics tapos gaganyanin, i mean wtf'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'GN2X2WkBgNd_yISc__Vw',
#     '_score': 0.87842023,
#     '_source': {'author': 'paojmn',
#      'date': 'Mon Apr 01 15:50:05 +0000 2019',
#      'message': "RT @cxIors: No loona so I'm skipping class fuck education https://t.co/Hdx8LBNndI"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'qd2Z2WkBgNd_yIScvfgR',
#     '_score': 0.87842023,
#     '_source': {'author': 'iamadisonpuente',
#      'date': 'Mon Apr 01 15:52:00 +0000 2019',
#      'message': 'RT @yyazziee: Guys who care about their education and future are so attractive'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Vd2b2WkBgNd_yIScBfuj',
#     '_score': 0.87842023,
#     '_source': {'author': 'siacareers',
#      'date': 'Mon Apr 01 15:53:24 +0000 2019',
#      'message': 'Council on Foreign Relations - Digital Production Assistant, Education https://t.co/hKhk3wnOOn @PennStateSIA #siaworks'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '1t2c2WkBgNd_yIScn_6k',
#     '_score': 0.87842023,
#     '_source': {'author': 'leeannjung',
#      'date': 'Mon Apr 01 15:55:08 +0000 2019',
#      'message': 'Is that a yes or a no? #education #leadforward #kidsdeserveit https://t.co/R7hDPjdh8m'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'j92X2WkBgNd_yIScTvNF',
#     '_score': 0.87786144,
#     '_source': {'author': 'Nataly4xs',
#      'date': 'Mon Apr 01 15:49:20 +0000 2019',
#      'message': '@manululu76 @Sandrine1340 @colineva1973 @Thonyti77 Un vrai baka , toute une education à refaire !'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Td2W2WkBgNd_yIScufLm',
#     '_score': 0.86619115,
#     '_source': {'author': 'nikitaxsaini',
#      'date': 'Mon Apr 01 15:48:42 +0000 2019',
#      'message': 'RT @yyazziee: Guys who care about their education and future are so attractive'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'aN2b2WkBgNd_yIScifwI',
#     '_score': 0.86619115,
#     '_source': {'author': 'stephent425',
#      'date': 'Mon Apr 01 15:53:57 +0000 2019',
#      'message': 'RT @KNayyeh: At least they have free healthcare and education https://t.co/9ZfptE2IEJ'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'AN2W2WkBgNd_yIScJfEy',
#     '_score': 0.86619115,
#     '_source': {'author': 'vocalKun',
#      'date': 'Mon Apr 01 15:48:04 +0000 2019',
#      'message': "RT @cxIors: No loona so I'm skipping class fuck education https://t.co/Hdx8LBNndI"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'ht2W2WkBgNd_yISc1fJ_',
#     '_score': 0.86619115,
#     '_source': {'author': 'dodonani15',
#      'date': 'Mon Apr 01 15:48:49 +0000 2019',
#      'message': 'RT @ty4_e: Education under Occupation in Palestine 🇵🇸\nFreePalestine \n#GroupPalestine  #قروب_فلسطيني https://t.co/h2xozncU95'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Y92X2WkBgNd_yIScPPM4',
#     '_score': 0.86619115,
#     '_source': {'author': 'lunafreedme',
#      'date': 'Mon Apr 01 15:49:15 +0000 2019',
#      'message': "RT @cxIors: No loona so I'm skipping class fuck education https://t.co/Hdx8LBNndI"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'kN2c2WkBgNd_yIScDf1L',
#     '_score': 0.86619115,
#     '_source': {'author': 'MrsKCozart',
#      'date': 'Mon Apr 01 15:54:30 +0000 2019',
#      'message': 'We loved hearing about Mr. Bass’s experience in education! #wesERve https://t.co/2P00rLyQF9'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'S92W2WkBgNd_yISct_Js',
#     '_score': 0.86508334,
#     '_source': {'author': 'PROFIT1000xxx',
#      'date': 'Mon Apr 01 15:48:41 +0000 2019',
#      'message': 'RT @OfficialMack10: “If you think education is expensive, try ignorance”'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '_92b2WkBgNd_yISczPyV',
#     '_score': 0.86508334,
#     '_source': {'author': 'ubmosby',
#      'date': 'Mon Apr 01 15:54:15 +0000 2019',
#      'message': '@xrscherbatsky Önce You izle o bin basar sex education a'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Wd2V2WkBgNd_yISc3PDX',
#     '_score': 0.864924,
#     '_source': {'author': 'MariahGuerre1',
#      'date': 'Mon Apr 01 15:47:45 +0000 2019',
#      'message': 'RT @yyazziee: Guys who care about their education and future are so attractive'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'lN2Y2WkBgNd_yIScrvY6',
#     '_score': 0.864924,
#     '_source': {'author': 'DAZEDXUXI',
#      'date': 'Mon Apr 01 15:50:50 +0000 2019',
#      'message': "RT @cxIors: No loona so I'm skipping class fuck education https://t.co/Hdx8LBNndI"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '0d2Z2WkBgNd_yISc0fh6',
#     '_score': 0.864924,
#     '_source': {'author': 'cherrihyun',
#      'date': 'Mon Apr 01 15:52:05 +0000 2019',
#      'message': "RT @cxIors: No loona so I'm skipping class fuck education https://t.co/Hdx8LBNndI"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'jd2a2WkBgNd_yIScqPrh',
#     '_score': 0.864924,
#     '_source': {'author': '_drewsavannah',
#      'date': 'Mon Apr 01 15:53:00 +0000 2019',
#      'message': 'RT @yyazziee: Guys who care about their education and future are so attractive'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '4t2b2WkBgNd_yIScQ_t5',
#     '_score': 0.864924,
#     '_source': {'author': 'abby_linnette23',
#      'date': 'Mon Apr 01 15:53:39 +0000 2019',
#      'message': 'RT @yyazziee: Guys who care about their education and future are so attractive'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '7N2Z2WkBgNd_yIScWfc_',
#     '_score': 0.864924,
#     '_source': {'author': 'Gaithersburg_MS',
#      'date': 'Mon Apr 01 15:51:33 +0000 2019',
#      'message': 'GMS 7th graders discussing how education, transportation, utilities impact budgeting. https://t.co/TkPGMRJnfc'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '1d2X2WkBgNd_yISc5vSe',
#     '_score': 0.85888684,
#     '_source': {'author': 'Igorot23',
#      'date': 'Mon Apr 01 15:49:59 +0000 2019',
#      'message': 'RT @FumiYamOfficial: Education is the key to success. Congratulations, Yamyam #PBB8BigIslandAdventure https://t.co/Om93nd540F'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'l92Z2WkBgNd_yIScs_he',
#     '_score': 0.85888684,
#     '_source': {'author': 'mjshields',
#      'date': 'Mon Apr 01 15:51:57 +0000 2019',
#      'message': 'Alabama - Lower Percentage of College Freshmen in Need of Remedial Education: https://t.co/U03lCtBMr1'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'w92b2WkBgNd_yIScNvut',
#     '_score': 0.85888684,
#     '_source': {'author': 'tumiprudy',
#      'date': 'Mon Apr 01 15:53:36 +0000 2019',
#      'message': 'RT @AdvBarryRoux: Connection is the key to success.\n\nEducation is just a back up.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'yN2c2WkBgNd_yIScm_6a',
#     '_score': 0.85888684,
#     '_source': {'author': 'HeardAndrew',
#      'date': 'Mon Apr 01 15:55:07 +0000 2019',
#      'message': 'Good discussion\n\nhttps://t.co/Ll7G5ykQ5i @TheAgenda #ONpoli #training #education #university @spaikin https://t.co/vqWxWJmv66'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'CN2X2WkBgNd_yISchvQ3',
#     '_score': 0.85776794,
#     '_source': {'author': 'iknowdatsright',
#      'date': 'Mon Apr 01 15:49:34 +0000 2019',
#      'message': '@iheartmindy @Newsweek That class, Smolletting 101 may appear in our public education system.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '192Y2WkBgNd_yISczPZ7',
#     '_score': 0.85776794,
#     '_source': {'author': 'ndingurl',
#      'date': 'Mon Apr 01 15:50:58 +0000 2019',
#      'message': 'RT @yyazziee: Guys who care about their education and future are so attractive'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'MN2Y2WkBgNd_yISc8_cB',
#     '_score': 0.85776794,
#     '_source': {'author': 'PBVLibrary',
#      'date': 'Mon Apr 01 15:51:07 +0000 2019',
#      'message': 'Where will you fit in? #education #pbvusd #excellenceineducation #jobopportunities #wearepbv https://t.co/x2R23LNlaq'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'C92b2WkBgNd_yIScz_0w',
#     '_score': 0.85776794,
#     '_source': {'author': 'jennntrevino',
#      'date': 'Mon Apr 01 15:54:15 +0000 2019',
#      'message': 'RT @yyazziee: Guys who care about their education and future are so attractive'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '3N2c2WkBgNd_yIScMv2y',
#     '_score': 0.85776794,
#     '_source': {'author': 'gisellemco',
#      'date': 'Mon Apr 01 15:54:41 +0000 2019',
#      'message': 'RT @yyazziee: Guys who care about their education and future are so attractive'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'pd2Z2WkBgNd_yIScuviH',
#     '_score': 0.8469678,
#     '_source': {'author': 'abundantlyjoyfl',
#      'date': 'Mon Apr 01 15:51:59 +0000 2019',
#      'message': "RT @DeetSupreme: @BriansNewHeart @McDegga Profit doesn't belong in basic HC, prison systems, or education."}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'dt2X2WkBgNd_yIScvPSJ',
#     '_score': 0.8469678,
#     '_source': {'author': 'ViewforthHE',
#      'date': 'Mon Apr 01 15:49:48 +0000 2019',
#      'message': 'When the overall benefits to society of higher education outweigh the costs to society.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Pt2X2WkBgNd_yIScofQC',
#     '_score': 0.8456742,
#     '_source': {'author': 'ShmeatBoy',
#      'date': 'Mon Apr 01 15:49:41 +0000 2019',
#      'message': 'And your education!  Is not that also social, and and the twist will disappear.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'z92W2WkBgNd_yIScE_Cy',
#     '_score': 0.8456742,
#     '_source': {'author': 'aaronlpc',
#      'date': 'Mon Apr 01 15:48:00 +0000 2019',
#      'message': 'The World has changed...so should how we think about "education"\nhttps://t.co/f3xCfZtqf9'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Vt2X2WkBgNd_yIScrfTd',
#     '_score': 0.8456742,
#     '_source': {'author': 'cooch',
#      'date': 'Mon Apr 01 15:49:44 +0000 2019',
#      'message': 'Education disaster? Common Core has given us snowflakes instead of students https://t.co/oYs8Sfn04F'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Ut2Y2WkBgNd_yIScFfVn',
#     '_score': 0.8456742,
#     '_source': {'author': 'reyan_tv',
#      'date': 'Mon Apr 01 15:50:11 +0000 2019',
#      'message': 'degree certificate attestation| higher education commission of\xa0Pakistan https://t.co/6G7HQx9jrY https://t.co/pVKfiVNteF'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'h92Y2WkBgNd_yIScMPWx',
#     '_score': 0.8456742,
#     '_source': {'author': 'Mitchel26297591',
#      'date': 'Mon Apr 01 15:50:18 +0000 2019',
#      'message': '@chiproytx @benshapiro The federal department of education is a total waste of tax dollars!'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '8N2a2WkBgNd_yIScZfkS',
#     '_score': 0.8456742,
#     '_source': {'author': 'GTConsultant',
#      'date': 'Mon Apr 01 15:52:43 +0000 2019',
#      'message': 'The latest Differentiation Daily! https://t.co/5RFXoQJBXE Thanks to @tmj_FL_EDU @MEDixon215 @Mauvezin65 #education #edchat'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'mN2c2WkBgNd_yIScEv07',
#     '_score': 0.8444224,
#     '_source': {'author': 'MariettaPioneer',
#      'date': 'Mon Apr 01 15:54:32 +0000 2019',
#      'message': 'RT @MariettaGolf: Education through Athletics\n#WhyD3 #D3week #PioNation https://t.co/na57WKXFXG'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'HN2X2WkBgNd_yIScHfNP',
#     '_score': 0.8444224,
#     '_source': {'author': 'Hell0Sunshyne',
#      'date': 'Mon Apr 01 15:49:08 +0000 2019',
#      'message': '@FLOTUS Share that with the hubby.....the character education part.  #BeBest'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '4N2X2WkBgNd_yISc6vQP',
#     '_score': 0.8402032,
#     '_source': {'author': 'KTULNews',
#      'date': 'Mon Apr 01 15:50:00 +0000 2019',
#      'message': 'Oklahoma teachers start week of events backing education funding https://t.co/I3NbDym2nn https://t.co/9TpMbtY0T6'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'J92a2WkBgNd_yIScgPoh',
#     '_score': 0.8402032,
#     '_source': {'author': 'paradis_lance',
#      'date': 'Mon Apr 01 15:52:49 +0000 2019',
#      'message': 'The latest Paradis Press on Education! https://t.co/eNveZOMMhT Thanks to @gahumentre @theCodebrainer #edtech #edchat'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '5d2c2WkBgNd_yIScpf5q',
#     '_score': 0.8402032,
#     '_source': {'author': 'beccarosen',
#      'date': 'Mon Apr 01 15:55:10 +0000 2019',
#      'message': 'Wow this scandal goes right to the heart of our education system https://t.co/Tl3aAGBRQh'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'zd2c2WkBgNd_yIScnv42',
#     '_score': 0.83857375,
#     '_source': {'author': 'Goddess_Versa',
#      'date': 'Mon Apr 01 15:55:08 +0000 2019',
#      'message': 'This month will be a great one!! Finishing my education then back to work'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '892W2WkBgNd_yIScIPBU',
#     '_score': 0.83857375,
#     '_source': {'author': 'anniehb2268',
#      'date': 'Mon Apr 01 15:48:03 +0000 2019',
#      'message': "Said it before and I'll say it again.\nEducation not segregation. https://t.co/fyZT7hsnLp"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'lN2W2WkBgNd_yISc3PI2',
#     '_score': 0.83857375,
#     '_source': {'author': 'MichelleSLerner',
#      'date': 'Mon Apr 01 15:48:51 +0000 2019',
#      'message': '@ehanford In large part due to your reporting! Education reporting makes a difference @EdWriters'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'ot2a2WkBgNd_yISctfoj',
#     '_score': 0.83857375,
#     '_source': {'author': 'yoyobaba',
#      'date': 'Mon Apr 01 15:53:03 +0000 2019',
#      'message': '"education" fraud -  Here’s how charter schools are scamming the US government - https://t.co/Polx5IcM3e'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Vd2W2WkBgNd_yIScSPEv',
#     '_score': 0.82857925,
#     '_source': {'author': 'nicolasjsmith',
#      'date': 'Mon Apr 01 15:48:13 +0000 2019',
#      'message': "@papsby @Ankaman616 @Mullane45 builders is strong with sugar, don't they teach you anything private education?"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Vt2a2WkBgNd_yIScHflz',
#     '_score': 0.82857925,
#     '_source': {'author': 'DesignSrvcsNW',
#      'date': 'Mon Apr 01 15:52:24 +0000 2019',
#      'message': 'Wagner Education Center at The Center for Wooden Boats https://t.co/7P36op3pfr https://t.co/7P36op3pfr'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'ad2Z2WkBgNd_yIScEPfH',
#     '_score': 0.82726264,
#     '_source': {'author': 'KomfooYaw',
#      'date': 'Mon Apr 01 15:51:15 +0000 2019',
#      'message': '@ataaaaa_a just because you got an education, you think you know better than all us.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'xN2a2WkBgNd_yIScTflU',
#     '_score': 0.82726264,
#     '_source': {'author': 'sadaqatwapda5',
#      'date': 'Mon Apr 01 15:52:36 +0000 2019',
#      'message': '@Matiullahjan919 Wo salary bhonky ki leta hai education ki ni or wo acha bhonkta hai'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'jd2b2WkBgNd_yIScG_tU',
#     '_score': 0.82726264,
#     '_source': {'author': 'CSSC_NI',
#      'date': 'Mon Apr 01 15:53:28 +0000 2019',
#      'message': 'Read more about us in our recent #newsletter 👉 https://t.co/G6fthplcwP #education https://t.co/IE3qFXT7Eb'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'NN2a2WkBgNd_yIScC_mh',
#     '_score': 0.82472533,
#     '_source': {'author': 'DesignSrvcsNW',
#      'date': 'Mon Apr 01 15:52:20 +0000 2019',
#      'message': 'Wagner Education Center at The Center for Wooden Boats https://t.co/7P36op3pfr'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'w92a2WkBgNd_yIScTfkV',
#     '_score': 0.8223152,
#     '_source': {'author': 'peppersgrad',
#      'date': 'Mon Apr 01 15:52:36 +0000 2019',
#      'message': 'RT @BetsyDeVosED: #DidYouKnow: Under Tennessee’s Individualized Education Account Program, parents of students with disabilities are given…'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'sd2W2WkBgNd_yISc6PJZ',
#     '_score': 0.8223152,
#     '_source': {'author': 'Raeesah11_',
#      'date': 'Mon Apr 01 15:48:54 +0000 2019',
#      'message': 'RT @Cameron_Munk13: “What’s your major?”\n“Elementary education”\n“Oh you better marry rich then” https://t.co/zQYzgDN85b'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '1t2W2WkBgNd_yISc-fID',
#     '_score': 0.82021976,
#     '_source': {'author': 'kandrush14',
#      'date': 'Mon Apr 01 15:48:58 +0000 2019',
#      'message': 'Online Education - The Forgotten Frontier in Student Affairs | Student Affairs and Technology https://t.co/raxMWaMKKL'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'H92X2WkBgNd_yISck_RH',
#     '_score': 0.82021976,
#     '_source': {'author': 'mosyanworkshop',
#      'date': 'Mon Apr 01 15:49:38 +0000 2019',
#      'message': 'Education is what remains after one has forgotten what one has learned in school. #mosyanworkshop'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'ot2c2WkBgNd_yISchv5M',
#     '_score': 0.82021976,
#     '_source': {'author': 'educationnewsca',
#      'date': 'Mon Apr 01 15:55:02 +0000 2019',
#      'message': 'Appoinment of Ms. Lindsay Fagan as Director of Catholic Education - https://t.co/K4TD7D9tmV #Alberta #Appointments'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'iN2Y2WkBgNd_yIScMPXG',
#     '_score': 0.81097215,
#     '_source': {'author': 'simplylorilee',
#      'date': 'Mon Apr 01 15:50:18 +0000 2019',
#      'message': 'RT @BetsyDeVosED: #DidYouKnow: Under Tennessee’s Individualized Education Account Program, parents of students with disabilities are given…'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'wd2Z2WkBgNd_yIScP_fR',
#     '_score': 0.81097215,
#     '_source': {'author': 'PHLPromiseZone',
#      'date': 'Mon Apr 01 15:51:26 +0000 2019',
#      'message': '"Education is the foundation upon which we build our future." - Christine Gregoire #MondayMotivation https://t.co/7NBZZTGEuz'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'gd2b2WkBgNd_yIScFvs0',
#     '_score': 0.81097215,
#     '_source': {'author': 'deb38957303',
#      'date': 'Mon Apr 01 15:53:28 +0000 2019',
#      'message': '@tomselliott @dbongino Who voted her into office?  So sad what a Boston College education gets you.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'ZN2b2WkBgNd_yISc9P01',
#     '_score': 0.81097215,
#     '_source': {'author': 'peachypunk__',
#      'date': 'Mon Apr 01 15:54:25 +0000 2019',
#      'message': 'RT @afroamericunt: I’m 6’5, got tattoos, a felony, 3 baby mommas, and an 8th grad education'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'It2W2WkBgNd_yIScNPE3',
#     '_score': 0.81097215,
#     '_source': {'author': 'HanoiToon',
#      'date': 'Mon Apr 01 15:48:08 +0000 2019',
#      'message': 'RT @BeccyBeatles: Make sure you sign the petition!\n\n#racism #education #football @SRTRC_England @LiamLavery1 @WansbeckLabour \n\nhttps://t.co…'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Bd2W2WkBgNd_yIScJvG7',
#     '_score': 0.81097215,
#     '_source': {'author': 'haahdia',
#      'date': 'Mon Apr 01 15:48:04 +0000 2019',
#      'message': 'RT @Cameron_Munk13: “What’s your major?”\n“Elementary education”\n“Oh you better marry rich then” https://t.co/zQYzgDN85b'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'ft2X2WkBgNd_yIScR_MA',
#     '_score': 0.81097215,
#     '_source': {'author': 'mindygouldpta',
#      'date': 'Mon Apr 01 15:49:18 +0000 2019',
#      'message': 'RT @DianeRavitch: Charter School Power Broker Turns Public Education Into Private Profits — ProPublica https://t.co/OLdXvo2VWj'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'zd2Z2WkBgNd_yISczviK',
#     '_score': 0.81097215,
#     '_source': {'author': 'AliaZakri',
#      'date': 'Mon Apr 01 15:52:04 +0000 2019',
#      'message': 'RT @wef: Imaginary worlds, real skills. \n\n📕 Read more: https://t.co/AVl3nMJ3rc #innovation #education https://t.co/DQfJLLEzsw'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'At2b2WkBgNd_yIScUvxN',
#     '_score': 0.81097215,
#     '_source': {'author': 'callynt',
#      'date': 'Mon Apr 01 15:53:43 +0000 2019',
#      'message': 'RT @BetsyDeVosED: #DidYouKnow: Under Tennessee’s Individualized Education Account Program, parents of students with disabilities are given…'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '-92X2WkBgNd_yISc8vQz',
#     '_score': 0.8096357,
#     '_source': {'author': 'LoveBlessRepeat',
#      'date': 'Mon Apr 01 15:50:02 +0000 2019',
#      'message': 'RT @BetsyDeVosED: #DidYouKnow: Under Tennessee’s Individualized Education Account Program, parents of students with disabilities are given…'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '292Z2WkBgNd_yISc1vhS',
#     '_score': 0.8096357,
#     '_source': {'author': 'ShaunaGilligan1',
#      'date': 'Mon Apr 01 15:52:06 +0000 2019',
#      'message': "RT @President_MU: Who's that launching the Action Plan for Education with @campaignforleo @McHughJoeTD @mitchelloconnor @JohnHalligan? Yes…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '-d2b2WkBgNd_yIScTPub',
#     '_score': 0.8096357,
#     '_source': {'author': 'JoYsWaGgG',
#      'date': 'Mon Apr 01 15:53:42 +0000 2019',
#      'message': '@CheckInWithCody Never will be a troll no thanks I love education too much to tell lies.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'md2X2WkBgNd_yISczfTJ',
#     '_score': 0.8096357,
#     '_source': {'author': 'bigbloy',
#      'date': 'Mon Apr 01 15:49:53 +0000 2019',
#      'message': 'RT @wef: Imaginary worlds, real skills. \n\n📕 Read more: https://t.co/AVl3nMJ3rc #innovation #education https://t.co/DQfJLLEzsw'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Qd2X2WkBgNd_yIScovQ1',
#     '_score': 0.8096357,
#     '_source': {'author': 'JasonPtrDavies',
#      'date': 'Mon Apr 01 15:49:41 +0000 2019',
#      'message': '@AnthonySmithVP announces the shortlist for Student Choice Awards and Education Awards at #UCLEducationConference https://t.co/DHLZwIC9Hd'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'LN2Y2WkBgNd_yIScBfWw',
#     '_score': 0.8096357,
#     '_source': {'author': '1ReformAlliance',
#      'date': 'Mon Apr 01 15:50:07 +0000 2019',
#      'message': 'RT @BetsyDeVosED: #DidYouKnow: Under Tennessee’s Individualized Education Account Program, parents of students with disabilities are given…'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'td2c2WkBgNd_yIScHv1N',
#     '_score': 0.8096357,
#     '_source': {'author': 'wrenbrowning',
#      'date': 'Mon Apr 01 15:54:35 +0000 2019',
#      'message': 'RT @BetsyDeVosED: #DidYouKnow: Under Tennessee’s Individualized Education Account Program, parents of students with disabilities are given…'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'qN2Y2WkBgNd_yIScPfVr',
#     '_score': 0.80592626,
#     '_source': {'author': 'MosleyNylan',
#      'date': 'Mon Apr 01 15:50:21 +0000 2019',
#      'message': 'Imma definitely destroy the government with education👨🏾\u200d🎓🙏🏾‼️. Gotta do it for Nipsey ‼️. #AAMU22'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'a92b2WkBgNd_yIScDvtI',
#     '_score': 0.80592626,
#     '_source': {'author': 'Ramproz',
#      'date': 'Mon Apr 01 15:53:26 +0000 2019',
#      'message': "RT @cxIors: No loona so I'm skipping class fuck education https://t.co/Hdx8LBNndI"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '992W2WkBgNd_yIScIfDi',
#     '_score': 0.80592626,
#     '_source': {'author': 'kitziaavilaa',
#      'date': 'Mon Apr 01 15:48:03 +0000 2019',
#      'message': 'RT @yyazziee: Guys who care about their education and future are so attractive'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'vd2c2WkBgNd_yIScJP08',
#     '_score': 0.80592626,
#     '_source': {'author': 'StrictlyAsking',
#      'date': 'Mon Apr 01 15:54:37 +0000 2019',
#      'message': 'RT @HariVishalMudra: ప్రభుత్వ విద్యని బాగుచేసి నాణ్యమైన ఉచిత విద్యని అందింస్తాం!\n\nConceptual Education \n\n#JANASENARevolution2019 \n#JanaSena…'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
# ...
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Ct2a2WkBgNd_yISccvqv',
#     '_score': 0.6807756,
#     '_source': {'author': 'mackysmoke',
#      'date': 'Mon Apr 01 15:52:46 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'D92a2WkBgNd_yISc5vs-',
#     '_score': 0.6807756,
#     '_source': {'author': 'marants',
#      'date': 'Mon Apr 01 15:53:16 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'ut2a2WkBgNd_yIScv_rQ',
#     '_score': 0.6807756,
#     '_source': {'author': 'Bitchiarati',
#      'date': 'Mon Apr 01 15:53:06 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'xN2a2WkBgNd_yIScxfqT',
#     '_score': 0.6807756,
#     '_source': {'author': 'ravenkouhai',
#      'date': 'Mon Apr 01 15:53:07 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'r92b2WkBgNd_yIScKvtd',
#     '_score': 0.6807756,
#     '_source': {'author': 'ReanneGinn',
#      'date': 'Mon Apr 01 15:53:33 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'td2b2WkBgNd_yIScLfvQ',
#     '_score': 0.6807756,
#     '_source': {'author': 'gabbyboutilier',
#      'date': 'Mon Apr 01 15:53:34 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'ft2b2WkBgNd_yIScFfsB',
#     '_score': 0.6807756,
#     '_source': {'author': 'juliabrae',
#      'date': 'Mon Apr 01 15:53:28 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'jt2b2WkBgNd_yIScG_vS',
#     '_score': 0.6807756,
#     '_source': {'author': 'katiemale_',
#      'date': 'Mon Apr 01 15:53:29 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'mN2b2WkBgNd_yIScIPuF',
#     '_score': 0.6807756,
#     '_source': {'author': 'purplepillszz',
#      'date': 'Mon Apr 01 15:53:31 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'cd2b2WkBgNd_yIScEPs3',
#     '_score': 0.6807756,
#     '_source': {'author': 'CorneaMaria6',
#      'date': 'Mon Apr 01 15:53:26 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'p92b2WkBgNd_yIScJvtS',
#     '_score': 0.6807756,
#     '_source': {'author': 'sabtren',
#      'date': 'Mon Apr 01 15:53:32 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'sd2b2WkBgNd_yIScqvw8',
#     '_score': 0.6807756,
#     '_source': {'author': 'Caterfree10',
#      'date': 'Mon Apr 01 15:54:06 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'cd2b2WkBgNd_yIScjfxv',
#     '_score': 0.6807756,
#     '_source': {'author': 'noelanix7',
#      'date': 'Mon Apr 01 15:53:58 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'j92b2WkBgNd_yIScm_wF',
#     '_score': 0.6807756,
#     '_source': {'author': 'hyxa_',
#      'date': 'Mon Apr 01 15:54:02 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'mt2b2WkBgNd_yIScovyz',
#     '_score': 0.6807756,
#     '_source': {'author': 'Louna_Aboud',
#      'date': 'Mon Apr 01 15:54:04 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'X92b2WkBgNd_yISc8v1O',
#     '_score': 0.6807756,
#     '_source': {'author': 'ughshino',
#      'date': 'Mon Apr 01 15:54:24 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Yd2b2WkBgNd_yISc8v1n',
#     '_score': 0.6807756,
#     '_source': {'author': 'imannoyingduh',
#      'date': 'Mon Apr 01 15:54:24 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'V92b2WkBgNd_yISc7_1I',
#     '_score': 0.6807756,
#     '_source': {'author': 'luciacambeses_',
#      'date': 'Mon Apr 01 15:54:23 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Wt2b2WkBgNd_yISc8P1X',
#     '_score': 0.6807756,
#     '_source': {'author': 'angiejolieisgod',
#      'date': 'Mon Apr 01 15:54:24 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Nd2b2WkBgNd_yISc4P1e',
#     '_score': 0.6807756,
#     '_source': {'author': 'geewayisdead',
#      'date': 'Mon Apr 01 15:54:20 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Pt2b2WkBgNd_yISc4_3S',
#     '_score': 0.6807756,
#     '_source': {'author': 'TrueKingOfFish',
#      'date': 'Mon Apr 01 15:54:20 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Id2b2WkBgNd_yISc1_3T',
#     '_score': 0.6807756,
#     '_source': {'author': 'tmj_aus_edu',
#      'date': 'Mon Apr 01 15:54:17 +0000 2019',
#      'message': 'Click the link in our bio to see currently open #Education jobs like "2019/20 High School Math Teacher" at Leander ISD in #Austin, TX.'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Gd2c2WkBgNd_yIScTP7V',
#     '_score': 0.6807756,
#     '_source': {'author': 'minhpn77',
#      'date': 'Mon Apr 01 15:54:47 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Gt2c2WkBgNd_yIScTf7Q',
#     '_score': 0.6807756,
#     '_source': {'author': '_fallengod_',
#      'date': 'Mon Apr 01 15:54:48 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '9t2c2WkBgNd_yIScO_0k',
#     '_score': 0.6807756,
#     '_source': {'author': 'kerly_lynce',
#      'date': 'Mon Apr 01 15:54:43 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '-t2c2WkBgNd_yIScPP23',
#     '_score': 0.6807756,
#     '_source': {'author': 'm0usery',
#      'date': 'Mon Apr 01 15:54:43 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'v92c2WkBgNd_yIScJP3H',
#     '_score': 0.6807756,
#     '_source': {'author': 'lauriewells__',
#      'date': 'Mon Apr 01 15:54:37 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'I92c2WkBgNd_yIScU_7P',
#     '_score': 0.6807756,
#     '_source': {'author': 'Ghostt614',
#      'date': 'Mon Apr 01 15:54:49 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'G92W2WkBgNd_yIScMfF_',
#     '_score': 0.6807756,
#     '_source': {'author': 'angelynadarling',
#      'date': 'Mon Apr 01 15:48:07 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Jt2W2WkBgNd_yIScNfEe',
#     '_score': 0.6807756,
#     '_source': {'author': 'griiven_',
#      'date': 'Mon Apr 01 15:48:08 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '292W2WkBgNd_yIScFvCr',
#     '_score': 0.6807756,
#     '_source': {'author': 'frabel_a',
#      'date': 'Mon Apr 01 15:48:00 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': '0d2W2WkBgNd_yIScgfFC',
#     '_score': 0.6807756,
#     '_source': {'author': 'tesswoosley_',
#      'date': 'Mon Apr 01 15:48:28 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'ld2W2WkBgNd_yIScafED',
#     '_score': 0.6807756,
#     '_source': {'author': 'beccatilton',
#      'date': 'Mon Apr 01 15:48:21 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'mt2W2WkBgNd_yIScafGr',
#     '_score': 0.6807756,
#     '_source': {'author': 'nenokam',
#      'date': 'Mon Apr 01 15:48:22 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'yd2W2WkBgNd_yIScffFQ',
#     '_score': 0.6807756,
#     '_source': {'author': 'edithnoc',
#      'date': 'Mon Apr 01 15:48:27 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'ct2W2WkBgNd_yIScy_LY',
#     '_score': 0.6807756,
#     '_source': {'author': 'smolsyd',
#      'date': 'Mon Apr 01 15:48:47 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'i92W2WkBgNd_yISc1_JA',
#     '_score': 0.6807756,
#     '_source': {'author': 'BrieMonayy_',
#      'date': 'Mon Apr 01 15:48:50 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 's92W2WkBgNd_yISc6fI5',
#     '_score': 0.6807756,
#     '_source': {'author': 'Camm_Smiith',
#      'date': 'Mon Apr 01 15:48:54 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'nt2W2WkBgNd_yISc4fKa',
#     '_score': 0.6807756,
#     '_source': {'author': 'mb_writing_skam',
#      'date': 'Mon Apr 01 15:48:52 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'Ut2W2WkBgNd_yIScvPJu',
#     '_score': 0.6807756,
#     '_source': {'author': 'alexis_janelle9',
#      'date': 'Mon Apr 01 15:48:43 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'g92X2WkBgNd_yIScSPP4',
#     '_score': 0.6807756,
#     '_source': {'author': 'Ana_smith1369',
#      'date': 'Mon Apr 01 15:49:19 +0000 2019',
#      'message': 'RT @BernieSanders: How do we have trillions of dollars to spend on endless wars, but we don’t have the money for education and health care?…'}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'ad2X2WkBgNd_yIScP_MC',
#     '_score': 0.6807756,
#     '_source': {'author': 'camsaywhatsup',
#      'date': 'Mon Apr 01 15:49:16 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'cd2X2WkBgNd_yIScQfMC',
#     '_score': 0.6807756,
#     '_source': {'author': 'itsadinted',
#      'date': 'Mon Apr 01 15:49:17 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}},
#    {'_index': 'tweetstream',
#     '_type': 'tweet',
#     '_id': 'ct2X2WkBgNd_yIScQfMX',
#     '_score': 0.6807756,
#     '_source': {'author': 'AGirlNamedKen',
#      'date': 'Mon Apr 01 15:49:17 +0000 2019',
#      'message': "RT @ReadMoreScience: If a 16-year-old wanted to adopt a child, the government wouldn't allow it. She isn't done with her education, she can…"}}]}}
